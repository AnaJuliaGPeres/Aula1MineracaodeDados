# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaJuliaGPeres/Aula1MineracaodeDados/blob/main/pratica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prática

# %%
#GDOWN é uma biblioteca para baixar arquivos od drive
import gdown

# %%
#Apenas o hash do arquivo
# !gdown 1exmP2er4MvJ4yyaop3_yGhCYYmGb7s6A
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1exmP2er4MvJ4yyaop3_yGhCYYmGb7s6A
# To: /content/SuperMercados.xlsx
# 100% 97.5k/97.5k [00:00<00:00, 75.4MB/s]

# %%
import numpy as np #biblioteca responsavel por operações matematicas
import pandas as pd #biblioteca responsavel pela manipulação de dados
import matplotlib.pyplot as plt #biblioteca responsavel pela visualização de dados
import seaborn as sns #biblioteca reponsavel pela visualização de dados em alto nível

# %%
#Leitura de dados para um dataframe(df)
df=pd.read_excel('SuperMercados.xlsx')

# %%
#mostra apenas as primeiras cincos linhas do dataframe
df.head()
# Out:
#    Unnamed: 0 ID da fatura Filial Tipo de Cliente Gênero  \
# 0           0  750-67-8428      A          Member      F
# 1           1  226-31-3081      C          Normal      F
# 2           2  631-41-3108      A          Normal      M
# 3           3  123-19-1176      A          Member      M
# 4           4  373-73-7910      A          Normal      M
#
#          Linha de produto  Preço unitário  Quantidade    Total       Data  \
# 0          Saúde e beleza         1120.35           7  7842.45   1/5/2019
# 1  Acessórios eletrônicos          229.20           5  1146.00   3/8/2019
# 2   Casa e estilo de vida          694.95           7  4864.65   3/3/2019
# 3          Saúde e beleza          873.30           8  6986.40  1/27/2019
# 4      Esportes e viagens         1294.65           7  9062.55   2/8/2019
#
#       Tempo          Pagamento       COGS  porcentagem de margem bruta  \
# 0  13:08:00                PIX  4705.4700                   4761904762
# 1  10:29:00           Dinheiro  1031.4000                   4761904762
# 2  13:23:00  Cartão de Crédito  3405.2550                   4761904762
# 3  20:33:00                PIX  4191.8400                   4761904762
# 4  10:37:00                PIX  6796.9125                   4761904762
#
#    renda bruta  Avaliação
# 0       261415         91
# 1          382         96
# 2       162155         74
# 3        23288         84
# 4       302085         53

# %%
sns.heatmap(df.isnull(),
             yticklabels=False,
             cbar = False,
            cmap = 'gnuplot'   ) #Função do searborn para ver se algum dados esta faltando, caso estivesse faltando iria aparecer que estava inconsistente. (NaN = not a Number)
# Out:
# <AxesSubplot:>

# %%
#Para verificar os dados
df
# Out:
#      Unnamed: 0 ID da fatura Filial Tipo de Cliente Gênero  \
# 0             0  750-67-8428      A          Member      F
# 1             1  226-31-3081      C          Normal      F
# 2             2  631-41-3108      A          Normal      M
# 3             3  123-19-1176      A          Member      M
# 4             4  373-73-7910      A          Normal      M
# ..          ...          ...    ...             ...    ...
# 995         995  233-67-5758      C          Normal      M
# 996         996  303-96-2227      B          Normal      F
# 997         997  727-02-1313      A          Member      M
# 998         998  347-56-2442      A          Normal      M
# 999         999  849-09-3807      A          Member      F
#
#            Linha de produto  Preço unitário  Quantidade     Total       Data  \
# 0            Saúde e beleza         1120.35           7   7842.45   1/5/2019
# 1    Acessórios eletrônicos          229.20           5   1146.00   3/8/2019
# 2     Casa e estilo de vida          694.95           7   4864.65   3/3/2019
# 3            Saúde e beleza          873.30           8   6986.40  1/27/2019
# 4        Esportes e viagens         1294.65           7   9062.55   2/8/2019
# ..                      ...             ...         ...       ...        ...
# 995          Saúde e beleza          605.25           1    605.25  1/29/2019
# 996   Casa e estilo de vida         1460.70          10  14607.00   3/2/2019
# 997        Comida e bebidas          477.60           1    477.60   2/9/2019
# 998   Casa e estilo de vida          987.30           1    987.30  2/22/2019
# 999     Acessórios fashions         1325.10           7   9275.70  2/18/2019
#
#         Tempo          Pagamento        COGS  porcentagem de margem bruta  \
# 0    13:08:00                PIX   4705.4700                   4761904762
# 1    10:29:00           Dinheiro   1031.4000                   4761904762
# 2    13:23:00  Cartão de Crédito   3405.2550                   4761904762
# 3    20:33:00                PIX   4191.8400                   4761904762
# 4    10:37:00                PIX   6796.9125                   4761904762
# ..        ...                ...         ...                          ...
# 995  13:46:00                PIX    363.1500                   4761904762
# 996  17:16:00                PIX  10224.9000                   4761904762
# 997  13:22:00           Dinheiro    405.9600                   4761904762
# 998  15:33:00           Dinheiro    691.1100                   4761904762
# 999  13:28:00           Dinheiro   6956.7750                   4761904762
#
#      renda bruta  Avaliação
# 0         261415         91
# 1            382         96
# 2         162155         74
# 3          23288         84
# 4         302085         53
# ..           ...        ...
# 995        20175         62
# 996         4869         44
# 997         1592         77
# 998         3291         41
# 999        30919         66
#
# [1000 rows x 16 columns]

# %%
# Deletando a coluna "Unnamed: 0"
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#     ID da fatura Filial Tipo de Cliente Gênero        Linha de produto  \
# 0    750-67-8428      A          Member      F          Saúde e beleza
# 1    226-31-3081      C          Normal      F  Acessórios eletrônicos
# 2    631-41-3108      A          Normal      M   Casa e estilo de vida
# 3    123-19-1176      A          Member      M          Saúde e beleza
# 4    373-73-7910      A          Normal      M      Esportes e viagens
# ..           ...    ...             ...    ...                     ...
# 995  233-67-5758      C          Normal      M          Saúde e beleza
# 996  303-96-2227      B          Normal      F   Casa e estilo de vida
# 997  727-02-1313      A          Member      M        Comida e bebidas
# 998  347-56-2442      A          Normal      M   Casa e estilo de vida
# 999  849-09-3807      A          Member      F     Acessórios fashions
#
#      Preço unitário  Quantidade     Total       Data     Tempo  \
# 0           1120.35           7   7842.45   1/5/2019  13:08:00
# 1            229.20           5   1146.00   3/8/2019  10:29:00
# 2            694.95           7   4864.65   3/3/2019  13:23:00
# 3            873.30           8   6986.40  1/27/2019  20:33:00
# 4           1294.65           7   9062.55   2/8/2019  10:37:00
# ..              ...         ...       ...        ...       ...
# 995          605.25           1    605.25  1/29/2019  13:46:00
# 996         1460.70          10  14607.00   3/2/2019  17:16:00
# 997          477.60           1    477.60   2/9/2019  13:22:00
# 998          987.30           1    987.30  2/22/2019  15:33:00
# 999         1325.10           7   9275.70  2/18/2019  13:28:00
#
#              Pagamento        COGS  porcentagem de margem bruta  renda bruta  \
# 0                  PIX   4705.4700                   4761904762       261415
# 1             Dinheiro   1031.4000                   4761904762          382
# 2    Cartão de Crédito   3405.2550                   4761904762       162155
# 3                  PIX   4191.8400                   4761904762        23288
# 4                  PIX   6796.9125                   4761904762       302085
# ..                 ...         ...                          ...          ...
# 995                PIX    363.1500                   4761904762        20175
# 996                PIX  10224.9000                   4761904762         4869
# 997           Dinheiro    405.9600                   4761904762         1592
# 998           Dinheiro    691.1100                   4761904762         3291
# 999           Dinheiro   6956.7750                   4761904762        30919
#
#      Avaliação
# 0           91
# 1           96
# 2           74
# 3           84
# 4           53
# ..         ...
# 995         62
# 996         44
# 997         77
# 998         41
# 999         66
#
# [1000 rows x 15 columns]

# %%
#Deletando as colunas que não vão ser usadas
df.drop(columns=['ID da fatura','porcentagem de margem bruta','renda bruta'],inplace=True)

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A          Member      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A          Member      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A          Member      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A          Member      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data     Tempo          Pagamento        COGS  \
# 0             7   7842.45   1/5/2019  13:08:00                PIX   4705.4700
# 1             5   1146.00   3/8/2019  10:29:00           Dinheiro   1031.4000
# 2             7   4864.65   3/3/2019  13:23:00  Cartão de Crédito   3405.2550
# 3             8   6986.40  1/27/2019  20:33:00                PIX   4191.8400
# 4             7   9062.55   2/8/2019  10:37:00                PIX   6796.9125
# ..          ...       ...        ...       ...                ...         ...
# 995           1    605.25  1/29/2019  13:46:00                PIX    363.1500
# 996          10  14607.00   3/2/2019  17:16:00                PIX  10224.9000
# 997           1    477.60   2/9/2019  13:22:00           Dinheiro    405.9600
# 998           1    987.30  2/22/2019  15:33:00           Dinheiro    691.1100
# 999           7   9275.70  2/18/2019  13:28:00           Dinheiro   6956.7750
#
#      Avaliação
# 0           91
# 1           96
# 2           74
# 3           84
# 4           53
# ..         ...
# 995         62
# 996         44
# 997         77
# 998         41
# 999         66
#
# [1000 rows x 12 columns]

# %%
df.head()
# Out:
#   Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0      A          Member      F          Saúde e beleza         1120.35
# 1      C          Normal      F  Acessórios eletrônicos          229.20
# 2      A          Normal      M   Casa e estilo de vida          694.95
# 3      A          Member      M          Saúde e beleza          873.30
# 4      A          Normal      M      Esportes e viagens         1294.65
#
#    Quantidade    Total       Data     Tempo          Pagamento       COGS  \
# 0           7  7842.45   1/5/2019  13:08:00                PIX  4705.4700
# 1           5  1146.00   3/8/2019  10:29:00           Dinheiro  1031.4000
# 2           7  4864.65   3/3/2019  13:23:00  Cartão de Crédito  3405.2550
# 3           8  6986.40  1/27/2019  20:33:00                PIX  4191.8400
# 4           7  9062.55   2/8/2019  10:37:00                PIX  6796.9125
#
#    Avaliação
# 0         91
# 1         96
# 2         74
# 3         84
# 4         53

# %%
#trocando o nome menber por associado, na coluna tipo cliente
df.replace({'Tipo de Cliente': {'Member': 'Associado'}}, inplace=True)

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data     Tempo          Pagamento        COGS  \
# 0             7   7842.45   1/5/2019  13:08:00                PIX   4705.4700
# 1             5   1146.00   3/8/2019  10:29:00           Dinheiro   1031.4000
# 2             7   4864.65   3/3/2019  13:23:00  Cartão de Crédito   3405.2550
# 3             8   6986.40  1/27/2019  20:33:00                PIX   4191.8400
# 4             7   9062.55   2/8/2019  10:37:00                PIX   6796.9125
# ..          ...       ...        ...       ...                ...         ...
# 995           1    605.25  1/29/2019  13:46:00                PIX    363.1500
# 996          10  14607.00   3/2/2019  17:16:00                PIX  10224.9000
# 997           1    477.60   2/9/2019  13:22:00           Dinheiro    405.9600
# 998           1    987.30  2/22/2019  15:33:00           Dinheiro    691.1100
# 999           7   9275.70  2/18/2019  13:28:00           Dinheiro   6956.7750
#
#      Avaliação
# 0           91
# 1           96
# 2           74
# 3           84
# 4           53
# ..         ...
# 995         62
# 996         44
# 997         77
# 998         41
# 999         66
#
# [1000 rows x 12 columns]

# %%
df.head()
# Out:
#   Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0      A       Associado      F          Saúde e beleza         1120.35
# 1      C          Normal      F  Acessórios eletrônicos          229.20
# 2      A          Normal      M   Casa e estilo de vida          694.95
# 3      A       Associado      M          Saúde e beleza          873.30
# 4      A          Normal      M      Esportes e viagens         1294.65
#
#    Quantidade    Total       Data     Tempo          Pagamento       COGS  \
# 0           7  7842.45   1/5/2019  13:08:00                PIX  4705.4700
# 1           5  1146.00   3/8/2019  10:29:00           Dinheiro  1031.4000
# 2           7  4864.65   3/3/2019  13:23:00  Cartão de Crédito  3405.2550
# 3           8  6986.40  1/27/2019  20:33:00                PIX  4191.8400
# 4           7  9062.55   2/8/2019  10:37:00                PIX  6796.9125
#
#    Avaliação
# 0         91
# 1         96
# 2         74
# 3         84
# 4         53

# %%
#trocando o nome da coluna tempo por horário
df.rename(columns={'Tempo':'Horário'})
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data   Horário          Pagamento        COGS  \
# 0             7   7842.45   1/5/2019  13:08:00                PIX   4705.4700
# 1             5   1146.00   3/8/2019  10:29:00           Dinheiro   1031.4000
# 2             7   4864.65   3/3/2019  13:23:00  Cartão de Crédito   3405.2550
# 3             8   6986.40  1/27/2019  20:33:00                PIX   4191.8400
# 4             7   9062.55   2/8/2019  10:37:00                PIX   6796.9125
# ..          ...       ...        ...       ...                ...         ...
# 995           1    605.25  1/29/2019  13:46:00                PIX    363.1500
# 996          10  14607.00   3/2/2019  17:16:00                PIX  10224.9000
# 997           1    477.60   2/9/2019  13:22:00           Dinheiro    405.9600
# 998           1    987.30  2/22/2019  15:33:00           Dinheiro    691.1100
# 999           7   9275.70  2/18/2019  13:28:00           Dinheiro   6956.7750
#
#      Avaliação
# 0           91
# 1           96
# 2           74
# 3           84
# 4           53
# ..         ...
# 995         62
# 996         44
# 997         77
# 998         41
# 999         66
#
# [1000 rows x 12 columns]

# %%
df=df.rename(columns={'Tempo':'Horário'})

# %%
df.head()
# Out:
#   Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0      A       Associado      F          Saúde e beleza         1120.35
# 1      C          Normal      F  Acessórios eletrônicos          229.20
# 2      A          Normal      M   Casa e estilo de vida          694.95
# 3      A       Associado      M          Saúde e beleza          873.30
# 4      A          Normal      M      Esportes e viagens         1294.65
#
#    Quantidade    Total       Data   Horário          Pagamento       COGS  \
# 0           7  7842.45   1/5/2019  13:08:00                PIX  4705.4700
# 1           5  1146.00   3/8/2019  10:29:00           Dinheiro  1031.4000
# 2           7  4864.65   3/3/2019  13:23:00  Cartão de Crédito  3405.2550
# 3           8  6986.40  1/27/2019  20:33:00                PIX  4191.8400
# 4           7  9062.55   2/8/2019  10:37:00                PIX  6796.9125
#
#    Avaliação
# 0         91
# 1         96
# 2         74
# 3         84
# 4         53

# %%
df.dtypes
# Out:
# Filial               object
# Tipo de Cliente      object
# Gênero               object
# Linha de produto     object
# Preço unitário      float64
# Quantidade            int64
# Total               float64
# Data                 object
# Horário              object
# Pagamento            object
# COGS                float64
# Avaliação             int64
# dtype: object

# %%
#Verificando na coluna Data quais meses existem nesse caso apenas 1,2,3
df['Data'].unique()
# Out:
# array(['1/5/2019', '3/8/2019', '3/3/2019', '1/27/2019', '2/8/2019',
#        '3/25/2019', '2/25/2019', '2/24/2019', '1/10/2019', '2/20/2019',
#        '2/6/2019', '3/9/2019', '2/12/2019', '2/7/2019', '3/29/2019',
#        '1/15/2019', '3/11/2019', '1/1/2019', '1/21/2019', '3/5/2019',
#        '3/15/2019', '2/17/2019', '3/2/2019', '3/22/2019', '3/10/2019',
#        '1/25/2019', '1/28/2019', '1/7/2019', '3/23/2019', '1/17/2019',
#        '2/2/2019', '3/4/2019', '3/16/2019', '2/27/2019', '2/10/2019',
#        '3/19/2019', '2/3/2019', '3/7/2019', '2/28/2019', '3/27/2019',
#        '1/20/2019', '3/12/2019', '2/15/2019', '3/6/2019', '2/14/2019',
#        '3/13/2019', '1/24/2019', '1/6/2019', '2/11/2019', '1/22/2019',
#        '1/13/2019', '1/9/2019', '1/12/2019', '1/26/2019', '1/23/2019',
#        '2/23/2019', '1/2/2019', '2/9/2019', '3/26/2019', '3/1/2019',
#        '2/1/2019', '3/28/2019', '3/24/2019', '2/5/2019', '1/19/2019',
#        '1/16/2019', '1/8/2019', '2/18/2019', '1/18/2019', '2/16/2019',
#        '2/22/2019', '1/29/2019', '1/4/2019', '3/30/2019', '1/30/2019',
#        '1/3/2019', '3/21/2019', '2/13/2019', '1/14/2019', '3/18/2019',
#        '3/20/2019', '2/21/2019', '1/31/2019', '1/11/2019', '2/26/2019',
#        '3/17/2019', '3/14/2019', '2/4/2019', '2/19/2019'], dtype=object)

# %%
#mostra apenas a coluna horario
df['Horário']
# Out:
# 0      13:08:00
# 1      10:29:00
# 2      13:23:00
# 3      20:33:00
# 4      10:37:00
#          ...
# 995    13:46:00
# 996    17:16:00
# 997    13:22:00
# 998    15:33:00
# 999    13:28:00
# Name: Horário, Length: 1000, dtype: object

# %%
#converte objeto para datatime64 (manipular data e hora)
df['Horário']=pd.to_datetime(df['Horário'])

# %%
df['Horário']
# Out:
# 0     2023-03-14 13:08:00
# 1     2023-03-14 10:29:00
# 2     2023-03-14 13:23:00
# 3     2023-03-14 20:33:00
# 4     2023-03-14 10:37:00
#               ...
# 995   2023-03-14 13:46:00
# 996   2023-03-14 17:16:00
# 997   2023-03-14 13:22:00
# 998   2023-03-14 15:33:00
# 999   2023-03-14 13:28:00
# Name: Horário, Length: 1000, dtype: datetime64[ns]

# %%
#para verificar se algum dado esta se repetindo = esse deve ser executado ja no começo pra verificar se ha dados repetidos
df.duplicated().sum()
# Out:
# 0

# %%
#comando para analisar os tipos de dados no seu dataframe
df.dtypes
# Out:
# Filial                      object
# Tipo de Cliente             object
# Gênero                      object
# Linha de produto            object
# Preço unitário             float64
# Quantidade                   int64
# Total                      float64
# Data                        object
# Horário             datetime64[ns]
# Pagamento                   object
# COGS                       float64
# Avaliação                    int64
# dtype: object

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data             Horário          Pagamento  \
# 0             7   7842.45   1/5/2019 2023-03-14 13:08:00                PIX
# 1             5   1146.00   3/8/2019 2023-03-14 10:29:00           Dinheiro
# 2             7   4864.65   3/3/2019 2023-03-14 13:23:00  Cartão de Crédito
# 3             8   6986.40  1/27/2019 2023-03-14 20:33:00                PIX
# 4             7   9062.55   2/8/2019 2023-03-14 10:37:00                PIX
# ..          ...       ...        ...                 ...                ...
# 995           1    605.25  1/29/2019 2023-03-14 13:46:00                PIX
# 996          10  14607.00   3/2/2019 2023-03-14 17:16:00                PIX
# 997           1    477.60   2/9/2019 2023-03-14 13:22:00           Dinheiro
# 998           1    987.30  2/22/2019 2023-03-14 15:33:00           Dinheiro
# 999           7   9275.70  2/18/2019 2023-03-14 13:28:00           Dinheiro
#
#            COGS  Avaliação
# 0     4705.4700         91
# 1     1031.4000         96
# 2     3405.2550         74
# 3     4191.8400         84
# 4     6796.9125         53
# ..          ...        ...
# 995    363.1500         62
# 996  10224.9000         44
# 997    405.9600         77
# 998    691.1100         41
# 999   6956.7750         66
#
# [1000 rows x 12 columns]

# %%
#criando um dicionario
meses={1: 'Janeiro',2: 'Fevereiro', 3: 'Março'}

# %%
#mapear o numero mes para string mes
df['Data']=pd.to_datetime(df['Data']).dt.month.map(meses)

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data             Horário          Pagamento  \
# 0             7   7842.45    Janeiro 2023-03-14 13:08:00                PIX
# 1             5   1146.00      Março 2023-03-14 10:29:00           Dinheiro
# 2             7   4864.65      Março 2023-03-14 13:23:00  Cartão de Crédito
# 3             8   6986.40    Janeiro 2023-03-14 20:33:00                PIX
# 4             7   9062.55  Fevereiro 2023-03-14 10:37:00                PIX
# ..          ...       ...        ...                 ...                ...
# 995           1    605.25    Janeiro 2023-03-14 13:46:00                PIX
# 996          10  14607.00      Março 2023-03-14 17:16:00                PIX
# 997           1    477.60  Fevereiro 2023-03-14 13:22:00           Dinheiro
# 998           1    987.30  Fevereiro 2023-03-14 15:33:00           Dinheiro
# 999           7   9275.70  Fevereiro 2023-03-14 13:28:00           Dinheiro
#
#            COGS  Avaliação
# 0     4705.4700         91
# 1     1031.4000         96
# 2     3405.2550         74
# 3     4191.8400         84
# 4     6796.9125         53
# ..          ...        ...
# 995    363.1500         62
# 996  10224.9000         44
# 997    405.9600         77
# 998    691.1100         41
# 999   6956.7750         66
#
# [1000 rows x 12 columns]

# %%
#transformar datatime em object (string), selecionado apenas o horario
df['Horário']=df['Horário'].dt.strftime('%H')

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data Horário          Pagamento        COGS  \
# 0             7   7842.45    Janeiro      13                PIX   4705.4700
# 1             5   1146.00      Março      10           Dinheiro   1031.4000
# 2             7   4864.65      Março      13  Cartão de Crédito   3405.2550
# 3             8   6986.40    Janeiro      20                PIX   4191.8400
# 4             7   9062.55  Fevereiro      10                PIX   6796.9125
# ..          ...       ...        ...     ...                ...         ...
# 995           1    605.25    Janeiro      13                PIX    363.1500
# 996          10  14607.00      Março      17                PIX  10224.9000
# 997           1    477.60  Fevereiro      13           Dinheiro    405.9600
# 998           1    987.30  Fevereiro      15           Dinheiro    691.1100
# 999           7   9275.70  Fevereiro      13           Dinheiro   6956.7750
#
#      Avaliação
# 0           91
# 1           96
# 2           74
# 3           84
# 4           53
# ..         ...
# 995         62
# 996         44
# 997         77
# 998         41
# 999         66
#
# [1000 rows x 12 columns]

# %%
time = []#lista vazia
for i in list(map(int,df['Horário'])):#laço for mapeando e transformando string para inteiro
   if i > 8 and i < 13:#9-12(manha)
     time.append('Manhã')#comando append vai inserir manha quando o criterio for verdadeiro na lista time
   elif i > 12 and i < 19:
      time.append('Tarde')
   else:
      time.append('Noite')
df['Horário'] = time #substituindo a coluna horario pela lista time

# %%
df.head()
# Out:
#   Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0      A       Associado      F          Saúde e beleza         1120.35
# 1      C          Normal      F  Acessórios eletrônicos          229.20
# 2      A          Normal      M   Casa e estilo de vida          694.95
# 3      A       Associado      M          Saúde e beleza          873.30
# 4      A          Normal      M      Esportes e viagens         1294.65
#
#    Quantidade    Total       Data Horário          Pagamento       COGS  \
# 0           7  7842.45    Janeiro   Tarde                PIX  4705.4700
# 1           5  1146.00      Março   Manhã           Dinheiro  1031.4000
# 2           7  4864.65      Março   Tarde  Cartão de Crédito  3405.2550
# 3           8  6986.40    Janeiro   Noite                PIX  4191.8400
# 4           7  9062.55  Fevereiro   Manhã                PIX  6796.9125
#
#    Avaliação
# 0         91
# 1         96
# 2         74
# 3         84
# 4         53

# %% [markdown]
# # Minerando dados e criando informação: Qual a linha de produtos tem a melhor avaliação; Agrupando dados, nesse caso a coluna linha de produtos com a avaliação, tirando a media das avalições(mean), e o comando reset_index(drop=falsE) evita apagar o indice de dados

# %%
agrupamento = df.groupby('Linha de produto')['Avaliação'].mean().reset_index(drop=False)

# %%
agrupamento
# Out:
#          Linha de produto  Avaliação
# 0  Acessórios eletrônicos  61.411765
# 1     Acessórios fashions  64.780899
# 2   Casa e estilo de vida  63.031250
# 3        Comida e bebidas  63.166667
# 4      Esportes e viagens  60.379518
# 5          Saúde e beleza  62.335526

# %%
#Arredondando para uma casa decimal
agrupamento_avaliaçao = agrupamento.round(1)

# %%
agrupamento_avaliaçao
# Out:
#          Linha de produto  Avaliação
# 0  Acessórios eletrônicos       61.4
# 1     Acessórios fashions       64.8
# 2   Casa e estilo de vida       63.0
# 3        Comida e bebidas       63.2
# 4      Esportes e viagens       60.4
# 5          Saúde e beleza       62.3

# %%
#classificando valores na ordem decrescente
agrupamento_avaliaçao = agrupamento_avaliaçao.sort_values(by = 'Avaliação', ascending = False)

# %%
Figura = sns.color_palette('gnuplot')#selecionando as cores do grafico
Figura.reverse()#invertendo a sequencia de cores

# %%
ax = sns.barplot(y = 'Linha de produto', x = 'Avaliação', data = agrupamento_avaliaçao, palette = Figura)

# %% [markdown]
# #Qual a linha de produto teve a maior media de vendas(renda bruta)?

# %%
agrupando_Produto_Total = df.groupby('Linha de produto')['Total'].mean().reset_index(drop=False)

# %%
agrupando_Produto_Total
# Out:
#          Linha de produto        Total
# 0  Acessórios eletrônicos  4278.573529
# 1     Acessórios fashions  4043.292135
# 2   Casa e estilo de vida  4455.973125
# 3        Comida e bebidas  3912.985345
# 4      Esportes e viagens  4351.833434
# 5          Saúde e beleza  4024.018421

# %%
agrupando_Produto_Total.round(1)
# Out:
#          Linha de produto   Total
# 0  Acessórios eletrônicos  4278.6
# 1     Acessórios fashions  4043.3
# 2   Casa e estilo de vida  4456.0
# 3        Comida e bebidas  3913.0
# 4      Esportes e viagens  4351.8
# 5          Saúde e beleza  4024.0

# %%
fig, ax = plt.subplots(figsize=(16,12))
ax = sns.scatterplot(x = 'Linha de produto', y = 'Total', data = agrupando_Produto_Total, s = 75)
plt.axhline(y=np.nanmean(df.Total), color='red', linestyle='--',linewidth=3, label='Média')
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# #Qual é a filial que tem a maior média de vendas (valor bruto)

# %%
agrupando_Filial_Total = df.groupby('Filial')['Total'].mean().reset_index(drop=False)

# %%
agrupando_Filial_Total.round(1)
# Out:
#   Filial   Total
# 0      A  4110.3
# 1      B  4179.1
# 2      C  4237.8

# %%
fig, ax = plt.subplots(figsize=(12,9))
ax = sns.scatterplot(x = 'Filial', y = 'Total', data = agrupando_Filial_Total, s = 75)
plt.axhline(y=np.nanmean(df.Total), color='red', linestyle='--',linewidth=3, label='Média')
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2], [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %% [markdown]
# #Distribuição das vendas em função da linha de produtos

# %%
fig, ax = plt.subplots(figsize = (12,9))
ax = sns.boxenplot(y ='Linha de produto', x = 'Quantidade', data =df)

# %% [markdown]
# #Quantidade em função dos três meses

# %%
agrupando_Data_Quantidade = df.groupby('Data')['Quantidade'].sum().reset_index(drop = False)

# %%
fig, ax = plt.subplots(figsize = (12,9))
ax = sns.lineplot(x= 'Data', y = 'Quantidade', data = agrupando_Data_Quantidade, marker='o',markersize=10)

# %%
agrupando_Data_Quantidade
# Out:
#         Data  Quantidade
# 0  Fevereiro        1654
# 1    Janeiro        1965
# 2      Março        1891

# %%
new_index = [1,0,2]

# %%
agrupando_Data_Quantidade = agrupando_Data_Quantidade.reindex(new_index)

# %% [markdown]
# # Proporção dos tipops de cliente (Normal / Associado)

# %%
plt.style.use('classic')
plt.style.use('bmh')
df.groupby('Tipo de Cliente').count()['Total'].plot(kind ='pie', autopct  ='%.1f', figsize=(12,9), subplots=True, wedgeprops=dict(width=0.20))
# Out:
# array([<AxesSubplot:ylabel='Total'>], dtype=object)

# %%
plt.style.use('classic')
plt.style.use('bmh')
df.groupby('Gênero').count()['Total'].plot(kind ='pie', autopct  ='%.1f', figsize=(12,9), subplots=True, wedgeprops=dict(width=0.20))
# Out:
# array([<AxesSubplot:ylabel='Total'>], dtype=object)

# %% [markdown]
# # Qual o tipo de pagamento mais comum?

# %%
plt.style.use('classic')
plt.style.use('bmh')
df.groupby('Pagamento').count()['Total'].plot(kind ='pie', autopct  ='%.1f', figsize=(12,9), subplots=True, wedgeprops=dict(width=0.20))
# Out:
# array([<AxesSubplot:ylabel='Total'>], dtype=object)

# %%
df.head()
# Out:
#   Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0      A       Associado      F          Saúde e beleza         1120.35
# 1      C          Normal      F  Acessórios eletrônicos          229.20
# 2      A          Normal      M   Casa e estilo de vida          694.95
# 3      A       Associado      M          Saúde e beleza          873.30
# 4      A          Normal      M      Esportes e viagens         1294.65
#
#    Quantidade    Total       Data Horário          Pagamento       COGS  \
# 0           7  7842.45    Janeiro   Tarde                PIX  4705.4700
# 1           5  1146.00      Março   Manhã           Dinheiro  1031.4000
# 2           7  4864.65      Março   Tarde  Cartão de Crédito  3405.2550
# 3           8  6986.40    Janeiro   Noite                PIX  4191.8400
# 4           7  9062.55  Fevereiro   Manhã                PIX  6796.9125
#
#    Avaliação
# 0         91
# 1         96
# 2         74
# 3         84
# 4         53

# %% [markdown]
# # Qual a parte do dia que mais rende money?

# %%
agrupamento_horario_total= df.groupby('Horário')['Total'].mean().reset_index(drop = False)

# %%
agrupamento_horario_total
# Out:
#   Horário        Total
# 0   Manhã  4077.974464
# 1   Noite  4196.399202
# 2   Tarde  4218.379511

# %%
sns.lineplot( x =  'Horário', y = 'Total', data = agrupamento_horario_total, marker='o',markersize=12, linewidth=2)
# Out:
# <AxesSubplot:xlabel='Horário', ylabel='Total'>

# %%
agrupamento_horario_total
# Out:
#   Horário        Total
# 0   Manhã  4077.974464
# 1   Noite  4196.399202
# 2   Tarde  4218.379511

# %%
new_index = [0,2,1]

# %%
agrupamento_horario_total=agrupamento_horario_total.reindex(new_index)

# %%
df.head()
# Out:
#   Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0      A       Associado      F          Saúde e beleza         1120.35
# 1      C          Normal      F  Acessórios eletrônicos          229.20
# 2      A          Normal      M   Casa e estilo de vida          694.95
# 3      A       Associado      M          Saúde e beleza          873.30
# 4      A          Normal      M      Esportes e viagens         1294.65
#
#    Quantidade    Total       Data Horário          Pagamento       COGS  \
# 0           7  7842.45    Janeiro   Tarde                PIX  4705.4700
# 1           5  1146.00      Março   Manhã           Dinheiro  1031.4000
# 2           7  4864.65      Março   Tarde  Cartão de Crédito  3405.2550
# 3           8  6986.40    Janeiro   Noite                PIX  4191.8400
# 4           7  9062.55  Fevereiro   Manhã                PIX  6796.9125
#
#    Avaliação
# 0         91
# 1         96
# 2         74
# 3         84
# 4         53

# %%
df['Lucro']=df['Total'] - df['COGS']

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data Horário          Pagamento        COGS  \
# 0             7   7842.45    Janeiro   Tarde                PIX   4705.4700
# 1             5   1146.00      Março   Manhã           Dinheiro   1031.4000
# 2             7   4864.65      Março   Tarde  Cartão de Crédito   3405.2550
# 3             8   6986.40    Janeiro   Noite                PIX   4191.8400
# 4             7   9062.55  Fevereiro   Manhã                PIX   6796.9125
# ..          ...       ...        ...     ...                ...         ...
# 995           1    605.25    Janeiro   Tarde                PIX    363.1500
# 996          10  14607.00      Março   Tarde                PIX  10224.9000
# 997           1    477.60  Fevereiro   Tarde           Dinheiro    405.9600
# 998           1    987.30  Fevereiro   Tarde           Dinheiro    691.1100
# 999           7   9275.70  Fevereiro   Tarde           Dinheiro   6956.7750
#
#      Avaliação      Lucro
# 0           91  3136.9800
# 1           96   114.6000
# 2           74  1459.3950
# 3           84  2794.5600
# 4           53  2265.6375
# ..         ...        ...
# 995         62   242.1000
# 996         44  4382.1000
# 997         77    71.6400
# 998         41   296.1900
# 999         66  2318.9250
#
# [1000 rows x 13 columns]

# %%
#arrumar o lucro para a penultima linha 
df =df[['Filial', 'Tipo de Cliente', 'Gênero','Linha de produto','Preço unitário','Quantidade','Total','Data','Horário','Pagamento','COGS','Lucro','Avaliação']]

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data Horário          Pagamento        COGS  \
# 0             7   7842.45    Janeiro   Tarde                PIX   4705.4700
# 1             5   1146.00      Março   Manhã           Dinheiro   1031.4000
# 2             7   4864.65      Março   Tarde  Cartão de Crédito   3405.2550
# 3             8   6986.40    Janeiro   Noite                PIX   4191.8400
# 4             7   9062.55  Fevereiro   Manhã                PIX   6796.9125
# ..          ...       ...        ...     ...                ...         ...
# 995           1    605.25    Janeiro   Tarde                PIX    363.1500
# 996          10  14607.00      Março   Tarde                PIX  10224.9000
# 997           1    477.60  Fevereiro   Tarde           Dinheiro    405.9600
# 998           1    987.30  Fevereiro   Tarde           Dinheiro    691.1100
# 999           7   9275.70  Fevereiro   Tarde           Dinheiro   6956.7750
#
#          Lucro  Avaliação
# 0    3136.9800         91
# 1     114.6000         96
# 2    1459.3950         74
# 3    2794.5600         84
# 4    2265.6375         53
# ..         ...        ...
# 995   242.1000         62
# 996  4382.1000         44
# 997    71.6400         77
# 998   296.1900         41
# 999  2318.9250         66
#
# [1000 rows x 13 columns]
